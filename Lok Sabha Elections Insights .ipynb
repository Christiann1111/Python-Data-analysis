# %%
import pandas as pd

# %%
df_states=pd.read_csv('dim_states_codes.csv')

# %%
df1 = pd.read_csv('constituency_wise_results_2014.csv')
df1
# Out:
#                state     pc_name             candidate  sex   age category  \
# 0     Andhra Pradesh   Adilabad           GODAM NAGESH    M  49.0       ST
# 1     Andhra Pradesh   Adilabad                 NARESH    M  37.0       ST
# 2     Andhra Pradesh   Adilabad          RAMESH RATHOD    M  48.0       ST
# 3     Andhra Pradesh   Adilabad        RATHOD SADASHIV    M  55.0       ST
# 4     Andhra Pradesh   Adilabad       NETHAWATH RAMDAS    M  44.0       ST
# ...              ...         ...                   ...  ...   ...      ...
# 8350      Puducherry  Puducherry  PUVALA NAGESWARA RAO    M  60.0      GEN
# 8351      Puducherry  Puducherry            K. MANJINI    M  41.0      GEN
# 8352      Puducherry  Puducherry            R. VALAVAN    M  40.0      GEN
# 8353      Puducherry  Puducherry             V. VIJAYA    F  29.0      GEN
# 8354      Puducherry  Puducherry     None of the Above  NaN   NaN      NaN
#
#      party    party_symbol  general_votes  postal_votes  total_votes  \
# 0      TRS             Car         425762          5085       430847
# 1      INC            Hand         257994          1563       259557
# 2      TDP         Bicycle         182879          1319       184198
# 3      BSP        Elephant          94363            57        94420
# 4      IND  Auto- Rickshaw          41028             4        41032
# ...    ...             ...            ...           ...          ...
# 8350   IND  Sewing Machine            465             0          465
# 8351   IND         Coconut            767             0          767
# 8352   IND    Carrom Board            497             0          497
# 8353   IND    Green Chilli            746             0          746
# 8354  NOTA            NOTA          22267             1        22268
#
#       total_electors
# 0            1386282
# 1            1386282
# 2            1386282
# 3            1386282
# 4            1386282
# ...              ...
# 8350          901357
# 8351          901357
# 8352          901357
# 8353          901357
# 8354          901357
#
# [8355 rows x 12 columns]

# %%
df1.loc[(df1['party']=='NOTA')]
# Out:
#                state                         pc_name          candidate  sex  \
# 8     Andhra Pradesh                       Adilabad   None of the Above  NaN
# 26    Andhra Pradesh                     Peddapalle   None of the Above  NaN
# 44    Andhra Pradesh                     Karimnagar   None of the Above  NaN
# 61    Andhra Pradesh                       Nizamabad  None of the Above  NaN
# 72    Andhra Pradesh                       Zahirabad  None of the Above  NaN
# ...              ...                             ...                ...  ...
# 8278    NCT OF Delhi  NORTH WEST DELHI                None of the Above  NaN
# 8296    NCT OF Delhi  WEST DELHI                      None of the Above  NaN
# 8316    NCT OF Delhi  SOUTH DELHI                     None of the Above  NaN
# 8323     Lakshadweep                     Lakshadweep  None of the Above  NaN
# 8354      Puducherry                      Puducherry  None of the Above  NaN
#
#       age category party party_symbol  general_votes  postal_votes  \
# 8     NaN      NaN  NOTA         NOTA          17021            63
# 26    NaN      NaN  NOTA         NOTA           5344            17
# 44    NaN      NaN  NOTA         NOTA           5722            12
# 61    NaN      NaN  NOTA         NOTA           7244            22
# 72    NaN      NaN  NOTA         NOTA          11157            33
# ...   ...      ...   ...          ...            ...           ...
# 8278  NaN      NaN  NOTA         NOTA           8815            11
# 8296  NaN      NaN  NOTA         NOTA           7924             8
# 8316  NaN      NaN  NOTA         NOTA           4005             5
# 8323  NaN      NaN  NOTA         NOTA            123             0
# 8354  NaN      NaN  NOTA         NOTA          22267             1
#
#       total_votes  total_electors
# 8           17084         1386282
# 26           5361         1425355
# 44           5734         1550810
# 61           7266         1496193
# 72          11190         1445354
# ...           ...             ...
# 8278         8826         2194343
# 8296         7932         2039410
# 8316         4010         1752748
# 8323          123           49922
# 8354        22268          901357
#
# [511 rows x 12 columns]

# %%
df2 = pd.read_csv('constituency_wise_results_2019.csv')
df2
# Out:
#                state     pc_name  \
# 0     Andhra Pradesh      Aruku
# 1     Andhra Pradesh      Aruku
# 2     Andhra Pradesh      Aruku
# 3     Andhra Pradesh      Aruku
# 4     Andhra Pradesh      Aruku
# ...              ...         ...
# 8592      Puducherry  Puducherry
# 8593      Puducherry  Puducherry
# 8594      Puducherry  Puducherry
# 8595      Puducherry  Puducherry
# 8596      Puducherry  Puducherry
#
#                                               candidate     sex   age  \
# 0                                   KISHORE CHANDRA DEO    MALE  72.0
# 1     Dr. KOSURI KASI VISWANADHA VEERA VENKATA SATYA...    MALE  54.0
# 2                                      GODDETI. MADHAVI  FEMALE  26.0
# 3                                SHRUTI DEVI VYRICHERLA  FEMALE  46.0
# 4                                   GANGULAIAH VAMPURU.    MALE  49.0
# ...                                                 ...     ...   ...
# 8592                         TIRAVITAMANKAI@LOURDHUMARY  FEMALE  57.0
# 8593                                        IMS. BALAJI    MALE  32.0
# 8594                                           RAMESH.D    MALE  49.0
# 8595                                      V. RAMAMURTHI    MALE  74.0
# 8596                                               NOTA     NaN   NaN
#
#      category  party   party_symbol  general_votes  postal_votes  total_votes  \
# 0          ST    TDP        Bicycle         336163          1938       338101
# 1          ST    BJP          Lotus          17578           289        17867
# 2          ST  YSRCP    Ceiling Fan         557561          4629       562190
# 3          ST    INC           Hand          17656            74        17730
# 4          ST    JnP  Glass Tumbler          42245           549        42794
# ...       ...    ...            ...            ...           ...          ...
# 8592  GENERAL    IND          Slate            870             0          870
# 8593  GENERAL    IND            Bat           2546             0         2546
# 8594       SC    IND           Mike           1653             0         1653
# 8595  GENERAL    IND        Whistle            641             1          642
# 8596      NaN   NOTA            NaN          12192             7        12199
#
#       total_electors
# 0            1451418
# 1            1451418
# 2            1451418
# 3            1451418
# 4            1451418
# ...              ...
# 8592          973410
# 8593          973410
# 8594          973410
# 8595          973410
# 8596          973410
#
# [8597 rows x 12 columns]

# %% [markdown]
# # DATA CLEANING (Results 2014)

# %%
df1= df1.dropna()

# %%
 df1.state.replace("Andhra Pradesh","Telangana", inplace=True)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\1804269706.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.state.replace("Andhra Pradesh","Telangana", inplace=True)

# %%
distritos_multiples_estados = df1.groupby('pc_name')['state'].nunique()

distritos_conflictivos = distritos_multiples_estados[distritos_multiples_estados > 1]
print(distritos_conflictivos)
# Out:
# pc_name
# Aurangabad     2
# Hamirpur       2
# Maharajganj    2
# Name: state, dtype: int64

# %%
df_conflictivos = df1[df1['pc_name'].isin(distritos_conflictivos.index)]
#df_conflictivos.groupby('state').first()

df_conflictivos
# Out:
#               state      pc_name                  candidate sex   age  \
# 1130          Bihar  Maharajganj  JANARDAN SINGH "SIGRIWAL"   M  50.0
# 1131          Bihar  Maharajganj            NAGENDRA PRASAD   M  49.0
# 1132          Bihar  Maharajganj          PRABHU NATH SINGH   M  61.0
# 1133          Bihar  Maharajganj           MANORANJAN SINGH   M  54.0
# 1134          Bihar  Maharajganj                BYAS MANJHI   M  43.0
# ...             ...          ...                        ...  ..   ...
# 6937  Uttar Pradesh  Maharajganj             DAYARAM NISHAD   M  34.0
# 6938  Uttar Pradesh  Maharajganj               DINESH KUMAR   M  60.0
# 6939  Uttar Pradesh  Maharajganj                   DINANATH   M  41.0
# 6940  Uttar Pradesh  Maharajganj          RAKESH KUMAR GIRI   M  37.0
# 6941  Uttar Pradesh  Maharajganj         RAKESH KUMAR GUPTA   M  27.0
#
#      category  party    party_symbol  general_votes  postal_votes  \
# 1130      GEN    BJP           Lotus         320645           108
# 1131      GEN    BSP        Elephant          11187             2
# 1132      GEN    RJD  Hurricane Lamp         282171           167
# 1133      GEN  JD(U)           Arrow         149436            47
# 1134       SC   BMUP             Cot           4796             0
# ...       ...    ...             ...            ...           ...
# 6937      GEN    IND    Cup & Saucer           4210             0
# 6938       SC    IND   Walking Stick           1671             0
# 6939       SC    IND  Sewing Machine           2149             0
# 6940      GEN    IND             Hat           2545             0
# 6941      GEN    IND    Gas Cylinder           1828             0
#
#       total_votes  total_electors
# 1130       320753         1642068
# 1131        11189         1642068
# 1132       282338         1642068
# 1133       149483         1642068
# 1134         4796         1642068
# ...           ...             ...
# 6937         4210         1743131
# 6938         1671         1743131
# 6939         2149         1743131
# 6940         2545         1743131
# 6941         1828         1743131
#
# [98 rows x 12 columns]

# %%
df1
# Out:
#            state     pc_name             candidate sex   age category party  \
# 0      Telangana   Adilabad           GODAM NAGESH   M  49.0       ST   TRS
# 1      Telangana   Adilabad                 NARESH   M  37.0       ST   INC
# 2      Telangana   Adilabad          RAMESH RATHOD   M  48.0       ST   TDP
# 3      Telangana   Adilabad        RATHOD SADASHIV   M  55.0       ST   BSP
# 4      Telangana   Adilabad       NETHAWATH RAMDAS   M  44.0       ST   IND
# ...          ...         ...                   ...  ..   ...      ...   ...
# 8349  Puducherry  Puducherry          P. BAKKIARAJ   M  31.0       SC   IND
# 8350  Puducherry  Puducherry  PUVALA NAGESWARA RAO   M  60.0      GEN   IND
# 8351  Puducherry  Puducherry            K. MANJINI   M  41.0      GEN   IND
# 8352  Puducherry  Puducherry            R. VALAVAN   M  40.0      GEN   IND
# 8353  Puducherry  Puducherry             V. VIJAYA   F  29.0      GEN   IND
#
#         party_symbol  general_votes  postal_votes  total_votes  total_electors
# 0                Car         425762          5085       430847         1386282
# 1               Hand         257994          1563       259557         1386282
# 2            Bicycle         182879          1319       184198         1386282
# 3           Elephant          94363            57        94420         1386282
# 4     Auto- Rickshaw          41028             4        41032         1386282
# ...              ...            ...           ...          ...             ...
# 8349             Pot            610             0          610          901357
# 8350  Sewing Machine            465             0          465          901357
# 8351         Coconut            767             0          767          901357
# 8352    Carrom Board            497             0          497          901357
# 8353    Green Chilli            746             0          746          901357
#
# [7844 rows x 12 columns]

# %%
df1.loc[(df1['pc_name'] == 'Aurangabad')]

df1.drop(df1.loc[1418:1430].index, inplace=True)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\3281698746.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(df1.loc[1418:1430].index, inplace=True)

# %%
df1.loc[(df1['pc_name']== 'Hamirpur')] 
df1.drop(df1.loc[6665:6679].index, inplace=True)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\3982032461.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(df1.loc[6665:6679].index, inplace=True)

# %%
df1[df1['pc_name']=='Maharajganj']
df1.drop(df1.loc[1131:1139].index, inplace=True)
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\3076225221.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1.drop(df1.loc[1131:1139].index, inplace=True)

# %%
df1.loc[(df1['pc_name'] == 'Aurangabad')]
# Out:
#             state     pc_name                            candidate sex   age  \
# 3755  Maharashtra  Aurangabad           CHANDRAKANT BHAURAO KHAIRE   M  62.0
# 3756  Maharashtra  Aurangabad         JEVRIKAR INDRAKUMAR DNYANOBA   M  40.0
# 3757  Maharashtra  Aurangabad                   PATIL NITIN SURESH   M  44.0
# 3758  Maharashtra  Aurangabad      ABDUL KHUDUS ABDUL SAMAD SHAIKH   M  32.0
# 3759  Maharashtra  Aurangabad              JADHAV PUSHPA SHANTILAL   F  40.0
# 3760  Maharashtra  Aurangabad           BANSWAL MANNALAL PREMCHAND   M  47.0
# 3761  Maharashtra  Aurangabad  MOHMMAD KISMATWALA KASIM KISMATWALA   M  37.0
# 3762  Maharashtra  Aurangabad              GAYAKE SADASHIV AMBADAS   M  64.0
# 3763  Maharashtra  Aurangabad        SAYYAD SHAFIYODDIN VAHIYODDIN   M  46.0
# 3764  Maharashtra  Aurangabad              SUBHASH KALYANRAO LOMTE   M  62.0
# 3765  Maharashtra  Aurangabad            AHAMAD AZIZ AHAMAD MATEEN   M  53.0
# 3766  Maharashtra  Aurangabad              BANSODE UDHAV GOVARDHAN   M  31.0
# 3767  Maharashtra  Aurangabad           ANKUSH MUNJAJI TUPSAMUNDRE   M  39.0
# 3768  Maharashtra  Aurangabad           KAILAS CHANDRABHAN THENGDE   M  36.0
# 3769  Maharashtra  Aurangabad             JAGDIP VISHWANATH SHINDE   M  31.0
# 3770  Maharashtra  Aurangabad          TRIBHUVAN MADHUKAR PADMAKAR   M  45.0
# 3771  Maharashtra  Aurangabad            DANDGE NANASAHEB DAMODHAR   M  44.0
# 3772  Maharashtra  Aurangabad                          NADEEM RANA   M  40.0
# 3773  Maharashtra  Aurangabad                PHULARE SURESH ASARAM   M  33.0
# 3774  Maharashtra  Aurangabad          DR. FEROZ KHAN MURTUZA KHAN   M  44.0
# 3775  Maharashtra  Aurangabad              BALASAHEB ASARAM SARATE   M  45.0
# 3776  Maharashtra  Aurangabad              BALASAHEB VITTHAL AWARE   M  49.0
# 3777  Maharashtra  Aurangabad            JAWAHARLAL LAXMAN BHAGURE   M  30.0
# 3778  Maharashtra  Aurangabad               BHANUDAS RAMDAS SARODE   M  39.0
# 3779  Maharashtra  Aurangabad                    RAJU BABURAO DOLE   M  44.0
# 3780  Maharashtra  Aurangabad              NANDARKAR VISHAL UDDHAV   M  29.0
# 3781  Maharashtra  Aurangabad           SHAIK SAYYAD SHAIK MAHMOOD   M  33.0
#
#      category party             party_symbol  general_votes  postal_votes  \
# 3755      GEN   SHS              Bow & Arrow         520559           343
# 3756       SC   BSP                 Elephant          37412             7
# 3757      GEN   INC                     Hand         358812            90
# 3758      GEN  BMUP                      Cot           3774             1
# 3759       SC   ANC                      Bat           1037             1
# 3760       SC  PRCP                  Whistle            893             0
# 3761      GEN  GaAP                     Iron           1198             3
# 3762      GEN    SP                  Bicycle           2646             0
# 3763      GEN  WPOI                     Kite           2885             0
# 3764      GEN  AAAP                    Broom          11969             5
# 3765      GEN   IND           Auto- Rickshaw           1572             0
# 3766       SC   IND             Cup & Saucer           1795             0
# 3767       SC   IND  Pen Nib with Seven Rays           2019             0
# 3768      GEN   IND                    Dolli           2123             0
# 3769       SC   IND          Air Conditioner           1530             0
# 3770       SC   IND                  Almirah           6135             0
# 3771       SC   IND           Sewing Machine           5901             0
# 3772      GEN   IND              Ceiling Fan           2922             0
# 3773      GEN   IND                      Hat           2520             0
# 3774      GEN   IND                  Balloon            978             0
# 3775      GEN   IND                  Coconut            880             0
# 3776      GEN   IND             Gas Cylinder            614             0
# 3777       SC   IND               Television            877             1
# 3778      GEN   IND            Electric Pole            934             0
# 3779      GEN   IND          Pressure Cooker           1238             0
# 3780      GEN   IND             Green Chilli           1306             0
# 3781      GEN   IND                  Candles           1581             0
#
#       total_votes  total_electors
# 3755       520902         1589395
# 3756        37419         1589395
# 3757       358902         1589395
# 3758         3775         1589395
# 3759         1038         1589395
# 3760          893         1589395
# 3761         1201         1589395
# 3762         2646         1589395
# 3763         2885         1589395
# 3764        11974         1589395
# 3765         1572         1589395
# 3766         1795         1589395
# 3767         2019         1589395
# 3768         2123         1589395
# 3769         1530         1589395
# 3770         6135         1589395
# 3771         5901         1589395
# 3772         2922         1589395
# 3773         2520         1589395
# 3774          978         1589395
# 3775          880         1589395
# 3776          614         1589395
# 3777          878         1589395
# 3778          934         1589395
# 3779         1238         1589395
# 3780         1306         1589395
# 3781         1581         1589395

# %% [markdown]
# # DATA CLEANING (Results 2019)

# %%
#df2= df2.dropna()

# %%
distritos_multiples_estados = df2.groupby('pc_name')['state'].nunique()

distritos_conflictivos = distritos_multiples_estados[distritos_multiples_estados > 1]
print(distritos_conflictivos)
# Out:
# pc_name
# Aurangabad     2
# Hamirpur       2
# Maharajganj    2
# Name: state, dtype: int64

# %%
df_conflictivos = df2[df2['pc_name'].isin(distritos_conflictivos.index)]
#df_conflictivos.groupby('state').first()

df_conflictivos
# Out:
#               state      pc_name                         candidate   sex  \
# 819           Bihar  Maharajganj  Anirudh Prasad alias Sadhu Yadav  MALE
# 820           Bihar  Maharajganj         Janardan Singh 'Sigriwal"  MALE
# 821           Bihar  Maharajganj               Randhir Kumar Singh  MALE
# 822           Bihar  Maharajganj              Aravind Kumar Sharma  MALE
# 823           Bihar  Maharajganj                  Ali Azhar Ansari  MALE
# ...             ...          ...                               ...   ...
# 6633  Uttar Pradesh  Maharajganj                          PANNELAL  MALE
# 6634  Uttar Pradesh  Maharajganj                      PRAMOD KUMAR  MALE
# 6635  Uttar Pradesh  Maharajganj                        MOHANKUMAR  MALE
# 6636  Uttar Pradesh  Maharajganj                    LALDHARI YADAV  MALE
# 6637  Uttar Pradesh  Maharajganj                              NOTA   NaN
#
#        age category  party       party_symbol  general_votes  postal_votes  \
# 819   51.0  GENERAL    BSP           Elephant          24913           126
# 820   55.0  GENERAL    BJP              Lotus         543523          2829
# 821   36.0  GENERAL    RJD     Hurricane Lamp         314803           777
# 822   55.0  GENERAL   BJKD                Hat           8001             5
# 823   60.0  GENERAL  ManJP      Bead Necklace           3285            16
# ...    ...      ...    ...                ...            ...           ...
# 6633  33.0       SC    IND     Auto- Rickshaw           3871             1
# 6634  36.0  GENERAL    IND  Plastering Trowel           2236             0
# 6635  49.0  GENERAL    IND            Almirah           3066             0
# 6636  42.0  GENERAL    IND        Ganna Kisan           5386             1
# 6637   NaN      NaN   NOTA                NaN          10458            20
#
#       total_votes  total_electors
# 819         25039         1807768
# 820        546352         1807768
# 821        315580         1807768
# 822          8006         1807768
# 823          3301         1807768
# ...           ...             ...
# 6633         3872         1915408
# 6634         2236         1915408
# 6635         3066         1915408
# 6636         5387         1915408
# 6637        10478         1915408
#
# [88 rows x 12 columns]

# %%
df2.loc[(df2['pc_name'] == 'Aurangabad'),'state']

df2.drop(df2.loc[1135:1144].index, inplace=True)

# %%
df2[df2['pc_name']=='Maharajganj']
df2.drop(df2.loc[819:830].index ,inplace=True)

# %%
df2.loc[(df2['pc_name']== 'Hamirpur'),'state'] 
df2.drop(df2.loc[1857:1868].index, inplace=True)

# %% [markdown]
# # TASKS

# %%
df1_constitucies = df1.groupby('pc_name').sum()
df1_constitucies['total_electors']= df1.groupby('pc_name').first()[['total_electors']]
df1_constitucies['total_votes'] = pd.to_numeric(df1_constitucies['total_votes'], errors='coerce')
df1_constitucies['total_electors'] = pd.to_numeric(df1_constitucies['total_electors'], errors='coerce')

df1_constitucies ['VotersTurnoutRatio']=(df1_constitucies['total_votes']/df1_constitucies['total_electors'])*100
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\1341373320.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1_constitucies = df1.groupby('pc_name').sum()

# %%
df1_constitucies ['VotersTurnoutRatio']=(df1_constitucies['total_votes']/df1_constitucies['total_electors'])*100
#df2_constitucies ['VotersTurnoutRatio']=(df2_constitucies['total_votes']/df2_constitucies['total_electors'])*100

# %% [markdown]
# # TOP 5 Ratio Districts

# %%
df1_constitucies.sort_values(by='VotersTurnoutRatio',ascending=False).head(5)
# Out:
#                age  general_votes  postal_votes  total_votes  total_electors  \
# pc_name
# Dhubri       724.0        1363312           501      1363813         1550166
# Nagaland     195.0        1035666           548      1036214         1182972
# Tamluk       440.0        1323457          2584      1326041         1527273
# Lakshadweep  245.0          43116             0        43116           49922
# Kanthi       336.0        1279507          1706      1281213         1490409
#
#              VotersTurnoutRatio
# pc_name
# Dhubri                87.978513
# Nagaland              87.594127
# Tamluk                86.824098
# Lakshadweep           86.366732
# Kanthi                85.963853

# %%
df1_constitucies.sort_values(by='VotersTurnoutRatio').head(5)
# Out:
#                age  general_votes  postal_votes  total_votes  total_electors  \
# pc_name
# Srinagar     652.0         307229             4       307233         1207230
# Anantnag     582.0         369302            41       369343         1301143
# Baramulla    735.0         461411            13       461424         1190766
# Kalyan       824.0         814423           588       815011         1922034
# Patna Sahib  952.0         872148          2387       874535         1946249
#
#              VotersTurnoutRatio
# pc_name
# Srinagar              25.449417
# Anantnag              28.386042
# Baramulla             38.750183
# Kalyan                42.403568
# Patna Sahib           44.934384

# %%
df2_constitucies = df2.groupby('pc_name').sum()
df2_constitucies['total_electors']= df2.groupby('pc_name').first()[['total_electors']]
df2_constitucies['total_votes'] = pd.to_numeric(df2_constitucies['total_votes'], errors='coerce')
df2_constitucies['total_electors'] = pd.to_numeric(df2_constitucies['total_electors'], errors='coerce')
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\1822082942.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2_constitucies = df2.groupby('pc_name').sum()

# %%
df2_constitucies ['VotersTurnoutRatio']=(df2_constitucies['total_votes']/df2_constitucies['total_electors'])*100

# %%
df2_constitucies.sort_values(by='VotersTurnoutRatio',ascending=False).head(5)
# Out:
#                   age  general_votes  postal_votes  total_votes  \
# pc_name
# Dhubri          683.0        1682616          2389      1685005
# Bishnupur       463.0        1417871          2777      1420648
# Barpeta         616.0        1452238          6311      1458549
# Jalpaiguri      708.0        1497711          3211      1500922
# ARUNACHAL EAST  276.0         282854         10927       293781
#
#                 total_electors  VotersTurnoutRatio
# pc_name
# Dhubri                 1858566           90.661564
# Bishnupur              1627199           87.306347
# Barpeta                1685149           86.553118
# Jalpaiguri             1735464           86.485343
# ARUNACHAL EAST          339788           86.460087

# %%
df2_constitucies.sort_values(by=['VotersTurnoutRatio']).head(5)
# Out:
#               age  general_votes  postal_votes  total_votes  total_electors  \
# pc_name
# Anantnag    878.0         122849          2047       124896         1397779
# Srinagar    568.0         186366           466       186832         1294671
# Baramulla   510.0         452114          3436       455550         1317738
# Hyderabad   686.0         877267           605       877872         1957931
# Kalyan     1266.0         887955          2358       890313         1965676
#
#            VotersTurnoutRatio
# pc_name
# Anantnag             8.935318
# Srinagar            14.430848
# Baramulla           34.570605
# Hyderabad           44.836718
# Kalyan              45.292968

# %% [markdown]
# # BOTTOM 5 RATIO Districts

# %%
df1_constitucies.sort_values(by=['VotersTurnoutRatio']).head(5)
# Out:
#                age  general_votes  postal_votes  total_votes  total_electors  \
# pc_name
# Srinagar     652.0         307229             4       307233         1207230
# Anantnag     582.0         369302            41       369343         1301143
# Baramulla    735.0         461411            13       461424         1190766
# Kalyan       824.0         814423           588       815011         1922034
# Patna Sahib  952.0         872148          2387       874535         1946249
#
#              VotersTurnoutRatio
# pc_name
# Srinagar              25.449417
# Anantnag              28.386042
# Baramulla             38.750183
# Kalyan                42.403568
# Patna Sahib           44.934384

# %%
df2_constitucies.sort_values(by=['VotersTurnoutRatio']).head(5)
# Out:
#               age  general_votes  postal_votes  total_votes  total_electors  \
# pc_name
# Anantnag    878.0         122849          2047       124896         1397779
# Srinagar    568.0         186366           466       186832         1294671
# Baramulla   510.0         452114          3436       455550         1317738
# Hyderabad   686.0         877267           605       877872         1957931
# Kalyan     1266.0         887955          2358       890313         1965676
#
#            VotersTurnoutRatio
# pc_name
# Anantnag             8.935318
# Srinagar            14.430848
# Baramulla           34.570605
# Hyderabad           44.836718
# Kalyan              45.292968

# %% [markdown]
# # STATE

# %% [markdown]
# # TOP 5 STATES

# %%
#df1.loc[(df1['state'] == 'Uttar Pradesh')&(df1['pc_name']=='Amethi')]

# %%
#df1.loc[(df1['state'] == 'Telangana')]

# %%
#df1.loc[(df1['state'] == 'Arunachal Pradesh')]

# %%
df1_states = df1.groupby('state').sum()

df1_states['total_electors']= district_totals.groupby('state').sum()
#
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\458405488.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1_states = df1.groupby('state').sum()
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\458405488.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1_states['total_electors']= district_totals.groupby('state').sum()

# %%
district_totals = df1.groupby(['state', 'pc_name'])['total_electors'].sum().reset_index()

# %%
# Drop duplicates based on 'state' and 'pc_name' to only keep one entry per district

unique_districts = df1.drop_duplicates(subset=['state', 'pc_name'])

# Now, sum the total_electors for each state
state_totals = unique_districts.groupby('state')['total_electors'].sum().reset_index()

# And also sum the total_electors for each district within each state
district_totals = unique_districts.groupby(['state', 'pc_name'])['total_electors'].sum().reset_index()
 



df1_states = df1.groupby('state').sum()

df1_states['total_electors']= district_totals.groupby('state').sum()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\2228670761.py:14: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1_states = df1.groupby('state').sum()
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\2228670761.py:16: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df1_states['total_electors']= district_totals.groupby('state').sum()

# %%
df1_states ['VotersTurnoutRatio']=(df1_states['total_votes']/df1_states['total_electors'])*100

# %%
df1_states.sort_values(by='VotersTurnoutRatio',ascending=False).head(5)
# Out:
#                          age  general_votes  postal_votes  total_votes  \
# state
# Nagaland               195.0        1035666           548      1036214
# Lakshadweep            245.0          43116             0        43116
# Tripura               1377.0        1985213         14833      2000046
# Dadra & Nagar Haveli   507.0         162324             0       162324
# Sikkim                 319.0         295308          9327       304635
#
#                       total_electors  VotersTurnoutRatio
# state
# Nagaland                     1182972           87.594127
# Lakshadweep                    49922           86.366732
# Tripura                      2388822           83.725200
# Dadra & Nagar Haveli          196597           82.566875
# Sikkim                        370770           82.162796

# %%
df2_states = df2.groupby('state').sum()

df2_states['total_electors']= district_totals.groupby('state').sum()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\51934008.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2_states = df2.groupby('state').sum()
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\51934008.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2_states['total_electors']= district_totals.groupby('state').sum()

# %%
district_totals = df2.groupby(['state', 'pc_name'])['total_electors'].sum().reset_index()

# %%
# Drop duplicates based on 'state' and 'pc_name' to only keep one entry per district
unique_districts = df2.drop_duplicates(subset=['state', 'pc_name'])

# Now, sum the total_electors for each state
state_totals = unique_districts.groupby('state')['total_electors'].sum().reset_index()

# And also sum the total_electors for each district within each state
district_totals = unique_districts.groupby(['state', 'pc_name'])['total_electors'].sum().reset_index()
 



df2_states = df2.groupby('state').sum()

df2_states['total_electors']= district_totals.groupby('state').sum()
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\2695226834.py:13: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2_states = df2.groupby('state').sum()
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\2695226834.py:15: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df2_states['total_electors']= district_totals.groupby('state').sum()

# %%
df2_states ['VotersTurnoutRatio']=(df2_states['total_votes']/df2_states['total_electors'])*100

# %%
df2_states.sort_values(by='VotersTurnoutRatio',ascending=False).head(5)
# Out:
#                  age  general_votes  postal_votes  total_votes  \
# state
# Lakshadweep    283.0          46877           132        47009
# Nagaland       215.0        1002142          4215      1006357
# Manipur       1030.0        1606408         10922      1617330
# Tripura       1183.0        2142275         10897      2153172
# West Bengal  23577.0       57097266        109710     57206976
#
#              total_electors  VotersTurnoutRatio
# state
# Lakshadweep           55189           85.178206
# Nagaland            1213777           82.911194
# Manipur             1959563           82.535239
# Tripura             2614718           82.348154
# West Bengal        70001284           81.722752

# %% [markdown]
# # BOTTOM 5 STATES

# %%
df1_states.sort_values(by='VotersTurnoutRatio').head(5)
# Out:
#                      age  general_votes  postal_votes  total_votes  \
# state
# Jammu & Kashmir   3811.0        3531705          3608      3535313
# Bihar            27251.0       34019087         13964     34033051
# Uttar Pradesh    58564.0       79480185         55813     79535998
# Maharashtra      40979.0       48226986         57262     48284248
# Mizoram            197.0         419291          7415       426706
#
#                  total_electors  VotersTurnoutRatio
# state
# Jammu & Kashmir         7183129           49.216894
# Bihar                  62264007           54.659269
# Uttar Pradesh         137072564           58.024739
# Maharashtra            80798823           59.758603
# Mizoram                  702170           60.769614

# %%
df2_states.sort_values(by='VotersTurnoutRatio').head(5)
# Out:
#                      age  general_votes  postal_votes  total_votes  \
# state
# Jammu & Kashmir   3872.0        3509007         43615      3552622
# Bihar            27991.0       38765621        133436     38899057
# Uttar Pradesh    46814.0       86220645        260753     86481398
# NCT OF Delhi      7797.0        8663777         15235      8679012
# Maharashtra      40559.0       53838389        215856     54054245
#
#                  total_electors  VotersTurnoutRatio
# state
# Jammu & Kashmir         7922538           44.841969
# Bihar                  67665639           57.487164
# Uttar Pradesh         146134603           59.179275
# NCT OF Delhi           14327649           60.575270
# Maharashtra            88676946           60.956367

# %% [markdown]
# # 3

# %%
df1_x=pd.DataFrame(df1.groupby('pc_name')['total_votes'].sum()).reset_index() 

df1_xy=pd.DataFrame(df1.groupby(['pc_name'])['total_votes'].max()).reset_index() 

df1_xyz=pd.DataFrame(df1.groupby(['pc_name','party'])['total_votes'].max().reset_index())
df1_xyzz = df1_xyz.groupby(['pc_name'])['total_votes'].max()
merged_df_x1 = pd.merge(df1_xyzz, df1_xyz, on=['pc_name', 'total_votes'], suffixes=('_2014', '_2019'))



df1_x['total']=df1_xy['total_votes']
df1_x['party']=merged_df_x1['party']
df1_x['VoteRatio'] = (df1_x['total']/df1_x['total_votes']) *100
df1_x=df1_x.sort_values(by='VoteRatio',ascending=False)

###

df2_x=pd.DataFrame(df2.groupby('pc_name')['total_votes'].sum()).reset_index() 

df2_xy=pd.DataFrame(df2.groupby(['pc_name'])['total_votes'].max()).reset_index() 

df2_xyz=pd.DataFrame(df2.groupby(['pc_name','party'])['total_votes'].max().reset_index())

df2_xyzz = df2_xyz.groupby(['pc_name'])['total_votes'].max()
merged_df_x = pd.merge(df2_xyzz, df2_xyz, on=['pc_name', 'total_votes'], suffixes=('_2014', '_2019'))


df2_x['total']=df2_xy['total_votes']
df2_x['party']=merged_df_x['party']
df2_x['VoteRatio'] = (df2_x['total']/df2_x['total_votes']) *100
df2_x=df2_x.sort_values(by='VoteRatio',ascending=False)
##

merged_df = pd.merge(df1_x, df2_x, on=['pc_name', 'party'], suffixes=('_2014', '_2019'))
merged_df['vote_percentage_2019'] =  (df2_x['total']/df2_x['total_votes']) *100
##
sorted_df = merged_df.sort_values(by='VoteRatio_2019',ascending=False)

consecutive_party = sorted_df[['pc_name','party','VoteRatio_2019']]
##
consecutive_party
# Out:
#              pc_name party  VoteRatio_2019
# 0              Surat   BJP       74.470429
# 2            Navsari   BJP       74.367402
# 1           Vadodara   BJP       72.296842
# 51            Kangra   BJP       72.018463
# 46          Bhilwara   BJP       71.587233
# ..               ...   ...             ...
# 328         Ludhiana   INC       36.658214
# 315  Maldaha Dakshin   INC       34.730246
# 329           Ladakh   BJP       33.943967
# 99        Kishanganj   INC       33.316630
# 128        Kokrajhar   IND       32.751937
#
# [330 rows x 3 columns]

# %% [markdown]
# # 4

# %%
df_4_sum=pd.DataFrame(df1.groupby('pc_name')['total_votes'].sum()).reset_index() 
df_4 = pd.DataFrame(df1.groupby(['pc_name','party'])['total_votes'].max().reset_index())
df_4_1=df_4.groupby(['pc_name'])['total_votes'].max()
#df_4_1['total']=df_4_sum['total_votes']

df_4_merge=  pd.merge(df_4_1, df_4, on=['pc_name', 'total_votes'])
#df_4_merge['VoteRatio']= (df_4_1['total_votes']/df_4_12['total_votes'])*100

#df_4_sum
merged_4=pd.merge(df_4_merge,df_4_sum,on=['pc_name'])

merged_4['ratio']=(merged_4['total_votes_x']/merged_4['total_votes_y'])*100

merged_4.sort_values(by='ratio',ascending=False)
# Out:
#            pc_name  total_votes_x party  total_votes_y      ratio
# 457          Surat         718412   BJP         936986  76.672650
# 491       Vadodara         845464   BJP        1143524  73.934959
# 357        Navsari         820831   BJP        1151425  71.288273
# 328   Mumbai North         664004   BJP         937804  70.804134
# 170    Gandhinagar         773539   BJP        1122718  68.898780
# ..             ...            ...   ...            ...        ...
# 13     Alipurduars         362453  AITC        1203681  30.112048
# 398        Raiganj         317515   CPM        1097264  28.936974
# 303  Mahabubabad           320569   TRS        1117668  28.681952
# 292       Ludhiana         300459   INC        1097237  27.383236
# 285         Ladakh          31111   BJP         116822  26.631114
#
# [508 rows x 5 columns]

# %%
df_4_sum2=pd.DataFrame(df2.groupby('pc_name')['total_votes'].sum()).reset_index() 
df_42 = pd.DataFrame(df2.groupby(['pc_name','party'])['total_votes'].max().reset_index())
df_4_12=df_42.groupby(['pc_name'])['total_votes'].max()
#df_4_1['total']=df_4_sum['total_votes']

df_4_merge2=  pd.merge(df_4_12, df_42, on=['pc_name', 'total_votes'])
#df_4_merge['VoteRatio']= (df_4_1['total_votes']/df_4_12['total_votes'])*100

#df_4_sum
merged_42=pd.merge(df_4_merge2,df_4_sum2,on=['pc_name'])

merged_42['ratio']=(merged_42['total_votes_x']/merged_42['total_votes_y'])*100

merged_42.sort_values(by='ratio',ascending=False)
# Out:
#         pc_name  total_votes_x  party  total_votes_y      ratio
# 489       Surat         795651    BJP        1068412  74.470429
# 382     Navsari         972739    BJP        1308018  74.367402
# 523    Vadodara         883719    BJP        1222348  72.296842
# 267      Kangra         725218    BJP        1006989  72.018463
# 97     Bhilwara         938160    BJP        1310513  71.587233
# ..          ...            ...    ...            ...        ...
# 289  Kishanganj         367017    INC        1101603  33.316630
# 291   Kokrajhar         484560    IND        1479485  32.751937
# 41   Aurangabad         389042  AIMIM        1198221  32.468301
# 29     Anantnag          40180    JKN         124896  32.170766
# 73    Baramulla         133426    JKN         455550  29.288991
#
# [540 rows x 5 columns]

# %%
df_42 = pd.DataFrame(df2.groupby(['pc_name','party'])['total_votes'].max().reset_index())
df_42_1=df_42.groupby(['pc_name'])['total_votes'].max()
df_42_merge=  pd.merge(df_42_1, df_42, on=['pc_name', 'total_votes'])
df_42_merge
# Out:
#              pc_name  total_votes party
# 0     ARUNACHAL EAST       153883   BJP
# 1     ARUNACHAL WEST       225796   BJP
# 2          Adilabad        377374   BJP
# 3               Agra       646875   BJP
# 4        Ahmadnagar        704660   BJP
# ..               ...          ...   ...
# 535         Warangal       612498   TRS
# 536           Wardha       578364   BJP
# 537          Wayanad       706367   INC
# 538  Yavatmal-Washim       542098   SHS
# 539        Zahirabad       434244   TRS
#
# [540 rows x 3 columns]

# %%
merge= pd.merge(merged_4,merged_42 ,on=['pc_name'], suffixes=('_2014','_2019'))

# %%
merge['difference']= merge['ratio_2019'] - merge['ratio_2014']

# %%
Q4 = merge.loc[merge['party_2014']!=merge['party_2019']].sort_values(by='difference',ascending=False).head(10)

# %%
Q4[['pc_name','party_2014','party_2019','difference']]
# Out:
#                  pc_name party_2014 party_2019  difference
# 13           Alipurduars       AITC        BJP   24.285485
# 245        Kanniyakumari        BJP        INC   22.031758
# 41   Autonomous District        INC        BJP   21.626720
# 418              Sambhal        BJP         SP   21.269556
# 85             Bhagalpur        RJD      JD(U)   21.095067
# 223          Jhanjharpur        BJP      JD(U)   20.849928
# 382           Puducherry      AINRC        INC   20.629751
# 115        Chikkballapur        INC        BJP   19.947592
# 174             Ghazipur        BJP        BSP   19.914706
# 266                Kolar        INC        BJP   19.017556

# %% [markdown]
# # 5

# %%
 #Sort the data by constituency and total votes to find the winner and runner-up
df1_sorted = df1.sort_values(by=['pc_name', 'total_votes'], ascending=[True, False])

# Identify the winner and runner-up in each constituency
df1_sorted['rank'] = df1_sorted.groupby('pc_name')['total_votes'].rank(method='first', ascending=False)

# Calculate the margin only for winners (rank == 1)
winners = df1_sorted[df1_sorted['rank'] == 1]
runners_up = df1_sorted[df1_sorted['rank'] == 2]

# Merge winners and runners-up to calculate the margin
margins = pd.merge(winners, runners_up, on='pc_name', suffixes=('_winner', '_runner_up'))
margins['margin'] = margins['total_votes_winner'] - margins['total_votes_runner_up']

# Sort by the margin and get the top 5 candidates
top_5_candidates = margins.nlargest(5, 'margin')

# Display the relevant information
top_5_candidates[['state_winner', 'pc_name', 'candidate_winner', 'party_winner', 'margin']]
# Out:
#       state_winner    pc_name         candidate_winner party_winner  margin
# 491        Gujarat   Vadodara            NARENDRA MODI          BJP  570128
# 177  Uttar Pradesh  Ghaziabad        VIJAY KUMAR SINGH          BJP  567260
# 357        Gujarat    Navsari              C. R. PATIL          BJP  558116
# 213      Rajasthan     Jaipur         RAMCHARAN BOHARA          BJP  539345
# 457        Gujarat      Surat  DARSHANA VIKRAM JARDOSH          BJP  533190

# %%
 #Sort the data by constituency and total votes to find the winner and runner-up
df2_sorted = df2.sort_values(by=['pc_name', 'total_votes'], ascending=[True, False])

# Identify the winner and runner-up in each constituency
df2_sorted['rank'] = df2_sorted.groupby('pc_name')['total_votes'].rank(method='first', ascending=False)

# Calculate the margin only for winners (rank == 1)
winners = df2_sorted[df2_sorted['rank'] == 1]
runners_up = df2_sorted[df2_sorted['rank'] == 2]

# Merge winners and runners-up to calculate the margin
margins = pd.merge(winners, runners_up, on='pc_name', suffixes=('_winner', '_runner_up'))
margins['margin'] = margins['total_votes_winner'] - margins['total_votes_runner_up']

# Sort by the margin and get the top 5 candidates
top_5_candidates2 = margins.nlargest(5, 'margin')

# Display the relevant information
top_5_candidates2[['state_winner', 'pc_name', 'candidate_winner', 'party_winner', 'margin']]
# Out:
#     state_winner    pc_name         candidate_winner party_winner  margin
# 382      Gujarat    Navsari              C. R. Patil          BJP  689668
# 276      Haryana     Karnal            Sanjay Bhatia          BJP  656142
# 171      Haryana  Faridabad              KRISHAN PAL          BJP  638239
# 97     Rajasthan   Bhilwara  SUBHASH CHANDRA BAHERIA          BJP  612000
# 523      Gujarat   Vadodara          RANJANBEN BHATT          BJP  589177

# %% [markdown]
# #### APRENDER METODO RANK(ENREALIDAD ESTE CODIGO ENTERO)

# %% [markdown]
# # 6

# %%
df1['total_votes'].sum()
# Out:
# 512337089

# %%
df_2014=pd.DataFrame(df1.groupby('party')['total_votes'].sum()).reset_index()
df_2014['sum']= (df1['total_votes'].sum())
df_2014['vote_percentage']= (df_2014['total_votes']/df_2014['sum'])*100

df_voteshare1=df_2014.sort_values(by=['total_votes'],ascending=False)
df_voteshare1
# Out:
#      party  total_votes        sum  vote_percentage
# 80     BJP    160285936  512337089        31.285249
# 163    INC     96321926  512337089        18.800498
# 110    BSP     22218655  512337089         4.336726
# 31    AITC     21209364  512337089         4.139728
# 384     SP     18442139  512337089         3.599610
# ..     ...          ...        ...              ...
# 4     ABAS          296  512337089         0.000058
# 424    VSP          263  512337089         0.000051
# 315  RJAVP          259  512337089         0.000051
# 358  RaJPa          217  512337089         0.000042
# 114   BVLP          161  512337089         0.000031
#
# [452 rows x 4 columns]

# %%
df_2019=pd.DataFrame(df2.groupby('party')['total_votes'].sum()).reset_index()
df_2019['sum']= (df2['total_votes'].sum())
df_2019['vote_percentage']= (df_2019['total_votes']/df_2019['sum'])*100

df_voteshare2=df_2019.sort_values(by=['total_votes'],ascending=False)
df_voteshare2
# Out:
#     party  total_votes        sum  vote_percentage
# 126   BJP    227420114  611276454        37.204134
# 238   INC    119212094  611276454        19.502157
# 44   AITC     24929330  611276454         4.078241
# 167   BSP     22180595  611276454         3.628570
# 240   IND     16480511  611276454         2.696081
# ..    ...          ...        ...              ...
# 197  DKSP          346  611276454         0.000057
# 620   ToP          330  611276454         0.000054
# 192  CoAP          275  611276454         0.000045
# 196  DJHP          273  611276454         0.000045
# 347  MLJK          265  611276454         0.000043
#
# [673 rows x 4 columns]

# %% [markdown]
# # 7

# %%
df_split = pd.DataFrame(df1.groupby(['state','party'])['total_votes'].sum().reset_index())

df_s=df_split.groupby('state')['total_votes'].sum()

df_split_1=pd.merge(df_split,df_s ,on='state')

df_split_1['ratio']= (df_split_1['total_votes_x']/df_split_1['total_votes_y'])*100
df_split_1
# Out:
#                           state    party  total_votes_x  total_votes_y  \
# 0     Andaman & Nicobar Islands     AAAP           3737         188764
# 1     Andaman & Nicobar Islands     AIFB            225         188764
# 2     Andaman & Nicobar Islands     AITC           2283         188764
# 3     Andaman & Nicobar Islands      BJP          90969         188764
# 4     Andaman & Nicobar Islands      BSP           1139         188764
# ...                         ...      ...            ...            ...
# 996                 West Bengal     SUCI         350616       51060534
# 997                 West Bengal     SWJP           5340       51060534
# 998                 West Bengal  TRMRPPI           1071       51060534
# 999                 West Bengal     WPOI          48006       51060534
# 1000                West Bengal     grac           2906       51060534
#
#           ratio
# 0      1.979721
# 1      0.119196
# 2      1.209447
# 3     48.191922
# 4      0.603399
# ...         ...
# 996    0.686667
# 997    0.010458
# 998    0.002098
# 999    0.094018
# 1000   0.005691
#
# [1001 rows x 5 columns]

# %%
df_s
# Out:
# state
# Andaman & Nicobar Islands      188764
# Arunachal Pradesh              590635
# Assam                        14938826
# Bihar                        34033051
# Chandigarh                     450349
# Dadra & Nagar Haveli           162324
# Daman & Diu                     85917
# Goa                            806897
# Gujarat                      25369118
# Haryana                      11460931
# Himachal Pradesh              3069345
# Jammu & Kashmir               3535313
# Jharkhand                    12792013
# Karnataka                    30780980
# Kerala                       17765332
# Lakshadweep                     43116
# Madhya Pradesh               29247970
# Maharashtra                  48284248
# Manipur                       1405132
# Meghalaya                     1047913
# Mizoram                        426706
# NCT OF Delhi                  8232076
# Nagaland                      1036214
# Puducherry                     717749
# Punjab                       13786378
# Rajasthan                    26782731
# Sikkim                         304635
# Tamil Nadu                   40025367
# Telangana                    48026634
# Tripura                       2000046
# Uttar Pradesh                79535998
# Uttarakhand                   4343847
# West Bengal                  51060534
# Name: total_votes, dtype: int64

# %%
#l=pd.DataFrame(df_split.groupby('state')['total_votes'].sum())

#df_split['ratio']=df_split.loc[df_split['state'],'total_votes'].sum()
#df1.sort_values(by='ratio',ascending=False)


df_split=pd.DataFrame(df1.groupby('state')['total_votes'].sum())
df_split['max']=df1.groupby('state')['total_votes'].max()


df_split['constituncices']=df1.groupby('state')['pc_name'].nunique()
df_split.sort_values(by='constituncices',ascending=False)
# Out:
#                            total_votes     max  constituncices
# state
# Uttar Pradesh                 79535998  758482              79
# Maharashtra                   48284248  664004              48
# West Bengal                   51060534  748764              42
# Telangana                     48026634  671983              42
# Bihar                         34033051  493461              39
# Tamil Nadu                    40025367  628499              39
# Madhya Pradesh                29247970  854972              29
# Karnataka                     30780980  718326              28
# Gujarat                       25369118  845464              26
# Rajasthan                     26782731  863358              25
# Kerala                        17765332  462525              20
# Jharkhand                     12792013  543491              14
# Assam                         14938826  764985              14
# Punjab                        13786378  533237              13
# Haryana                       11460931  652516              10
# NCT OF Delhi                   8232076  651395               7
# Jammu & Kashmir                3535313  619995               6
# Uttarakhand                    4343847  636769               5
# Himachal Pradesh               3069345  456163               4
# Tripura                        2000046  671665               2
# Goa                             806897  237903               2
# Meghalaya                      1047913  239301               2
# Manipur                        1405132  296770               2
# Arunachal Pradesh               590635  169367               2
# Chandigarh                      450349  191362               1
# Dadra & Nagar Haveli            162324   80790               1
# Mizoram                         426706  210485               1
# Sikkim                          304635  163698               1
# Puducherry                      717749  255826               1
# Nagaland                       1036214  713372               1
# Daman & Diu                      85917   46960               1
# Lakshadweep                      43116   21665               1
# Andaman & Nicobar Islands       188764   90969               1

# %% [markdown]
# ###### 2019

# %%
df_split2 = pd.DataFrame(df2.groupby(['state','party'])['total_votes'].sum().reset_index())

df_s2=df_split2.groupby('state')['total_votes'].sum()

df_split2_2=pd.merge(df_split2,df_s2 ,on='state')

df_split2_2['ratio']= (df_split2_2['total_votes_x']/df_split2_2['total_votes_y'])*100
df_split2_2.sort_values(by='ratio',ascending=False)

df_split2_2[(df_split2_2['state']=='Uttar Pradesh')&(df_split2_2['party']=='BJP')]
# Out:
#               state party  total_votes_x  total_votes_y      ratio
# 1152  Uttar Pradesh   BJP       42858171       86481398  49.557676

# %%
df_split22=pd.DataFrame(df2.groupby('state')['total_votes'].sum())
df_split22['max']=df2.groupby('state')['total_votes'].max()


df_split22['constituncices']=df2.groupby('state')['pc_name'].nunique()
df_split22.sort_values(by='constituncices',ascending=False)
# Out:
#                            total_votes      max  constituncices
# state
# Uttar Pradesh                 86481398   944503              80
# Maharashtra                   54054245   749085              48
# West Bengal                   57206976   791127              42
# Tamil Nadu                    43392884   793281              39
# Bihar                         38899057   692193              38
# Madhya Pradesh                36910610  1068569              29
# Karnataka                     35138682   878258              28
# Gujarat                       29081964   972739              26
# Rajasthan                     32441064   982942              25
# Andhra Pradesh                31612534   783499              25
# Odisha                        23794122   630179              21
# Kerala                        20385216   706367              20
# Telangana                     18642895   612498              17
# Assam                         17986066  1008936              14
# Jharkhand                     14961958   827234              14
# Punjab                        13765432   633427              13
# Chhattisgarh                  13614453   849374              11
# Haryana                       12681536   913222              10
# NCT OF Delhi                   8679012   865648               7
# Jammu & Kashmir                3552622   858066               6
# Uttarakhand                    4842925   772195               5
# Himachal Pradesh               2861967   725218               3
# Tripura                        2153172   573532               2
# Arunachal Pradesh               652091   225796               2
# Meghalaya                      1367231   419689               2
# Manipur                        1617330   363527               2
# Goa                             853203   244844               2
# Nagaland                       1006357   500510               1
# Puducherry                      790760   444981               1
# Mizoram                         499621   224286               1
# Dadra & Nagar Haveli            198983    90421               1
# Sikkim                          351746   166922               1
# Chandigarh                      456568   231188               1
# Lakshadweep                      47009    22851               1
# Daman & Diu                      87469    37597               1
# Andaman & Nicobar Islands       207296    95308               1

# %% [markdown]
# # 8

# %%
df_party1=(df1.groupby('party').sum().sort_values(by='total_votes', ascending=False).reset_index()).reset_index()
df_party2=(df2.groupby('party').sum().sort_values(by='total_votes', ascending=False).reset_index()).reset_index()

#df_party=df_party1.loc[(df_party1['index']==0)|(df_party1['index']==1)]

#df_party2=df_party2.loc[(df_party2['index']==0)|(df_party2['index']==1)]

df_parties = pd.merge(df_party1,df_party2, on='party')

df_parties1 = df_parties['total_votes_y']>df_parties['total_votes_x']
df_parties1 = df_parties.loc[(df_parties['index_x']==0)|(df_parties['index_x']==1)]
df_parties1
# Out:
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\2625532044.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_party1=(df1.groupby('party').sum().sort_values(by='total_votes', ascending=False).reset_index()).reset_index()
# C:\Users\chris\AppData\Local\Temp\ipykernel_47984\2625532044.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df_party2=(df2.groupby('party').sum().sort_values(by='total_votes', ascending=False).reset_index()).reset_index()
#    index_x party    age_x  general_votes_x  postal_votes_x  total_votes_x  \
# 0        0   BJP  21510.0        160001956          283980      160285936
# 1        1   INC  23389.0         96167281          154645       96321926
#
#    total_electors_x  index_y    age_y  general_votes_y  postal_votes_y  \
# 0         610361643        0  23614.0        226418770         1001344
# 1         658910303        1  23093.0        118848612          363482
#
#    total_votes_y  total_electors_y
# 0      227420114         729779718
# 1      119212094         703779880

# %%
df1_f=pd.DataFrame(df1.groupby(['pc_name','party'])['total_votes'].sum()).reset_index()
df1_g=pd.DataFrame(df1.groupby('pc_name')['total_votes'].sum()).reset_index()


df1_h=pd.merge(df1_f,df1_g,on='pc_name')
df1_h['difference']=(df1_h['total_votes_x']/df1_h['total_votes_y'])*100
df1_j=df1_h.loc[df1_h['party']=='BJP'].sort_values(by='difference',ascending=False)

df2_f=pd.DataFrame(df2.groupby(['pc_name','party'])['total_votes'].sum()).reset_index()
df2_g=pd.DataFrame(df2.groupby('pc_name')['total_votes'].sum()).reset_index()


df2_h=pd.merge(df2_f,df2_g,on='pc_name')
df2_h['difference']=(df2_h['total_votes_x']/df2_h['total_votes_y'])*100
df2_j=df2_h.loc[df2_h['party']=='BJP'].sort_values(by='difference',ascending=False)



df_k=pd.merge(df1_j,df2_j,on=['pc_name','party'])
df_k['Gain share vote %']=df_k['difference_y']- df_k['difference_x']
Share_vote_1= df_k.sort_values(by='Gain share vote %',ascending=False)
Share_vote_1[['pc_name','Gain share vote %']].head(5)
# Out:
#           pc_name  Gain share vote %
# 352  Tripura West          46.613564
# 344       Purulia          42.038969
# 349  Tripura East          39.669837
# 308      Ranaghat          35.321918
# 336      Jhargram          34.639860

# %%
df1_f=pd.DataFrame(df1.groupby(['pc_name','party'])['total_votes'].sum()).reset_index()
df1_g=pd.DataFrame(df1.groupby('pc_name')['total_votes'].sum()).reset_index()


df1_h=pd.merge(df1_f,df1_g,on='pc_name')
df1_h['difference']=(df1_h['total_votes_x']/df1_h['total_votes_y'])*100
df1_j=df1_h.loc[df1_h['party']=='INC'].sort_values(by='difference',ascending=False)

df2_f=pd.DataFrame(df2.groupby(['pc_name','party'])['total_votes'].sum()).reset_index()
df2_g=pd.DataFrame(df2.groupby('pc_name')['total_votes'].sum()).reset_index()


df2_h=pd.merge(df2_f,df2_g,on='pc_name')
df2_h['difference']=(df2_h['total_votes_x']/df2_h['total_votes_y'])*100
df2_j=df2_h.loc[df2_h['party']=='INC'].sort_values(by='difference',ascending=False)



df_k=pd.merge(df1_j,df2_j,on=['pc_name','party'])
df_k['Gain share vote %']=df_k['difference_y']- df_k['difference_x']
Share_vote_2= df_k.sort_values(by='Gain share vote %',ascending=False)
Share_vote_2[['pc_name','Gain share vote %']].head(5)
# Out:
#              pc_name  Gain share vote %
# 327            Karur          60.114480
# 294  Tiruchirappalli          53.941015
# 333            Arani          51.453923
# 316     Thiruvallur           50.916318
# 314      Krishnagiri          48.940994

# %%
df1_f=pd.DataFrame(df1.groupby(['pc_name','party'])['total_votes'].sum()).reset_index()
df1_g=pd.DataFrame(df1.groupby('pc_name')['total_votes'].sum()).reset_index()


df1_h=pd.merge(df1_f,df1_g,on=['pc_name'])
df1_h['difference']=(df1_h['total_votes_x']/df1_h['total_votes_y'])*100
df1_j=df1_h.loc[df1_h['party']=='INC'].sort_values(by='difference',ascending=False)

df2_f=pd.DataFrame(df2.groupby(['pc_name','party'])['total_votes'].sum()).reset_index()
df2_g=pd.DataFrame(df2.groupby('pc_name')['total_votes'].sum()).reset_index()


df2_h=pd.merge(df2_f,df2_g,on=['pc_name'])
df2_h['difference']=(df2_h['total_votes_x']/df2_h['total_votes_y'])*100
df2_j=df2_h.loc[df2_h['party']=='INC'].sort_values(by='difference',ascending=False)



df_k=pd.merge(df1_j,df2_j,on=['pc_name','party'])
df_k['d']=df_k['difference_y']- df_k['difference_x']
df_k=df_k.sort_values(by='d',ascending=False)

share_vote2=pd.merge(df1,df_k,on='pc_name').sort_values(by='d').head(40)
share_vote2
# Out:
#                  state                 pc_name  \
# 2866       Maharashtra  Ratnagiri - sindhudurg
# 2873       Maharashtra  Ratnagiri - sindhudurg
# 2872       Maharashtra  Ratnagiri - sindhudurg
# 2871       Maharashtra  Ratnagiri - sindhudurg
# 2870       Maharashtra  Ratnagiri - sindhudurg
# 2869       Maharashtra  Ratnagiri - sindhudurg
# 2868       Maharashtra  Ratnagiri - sindhudurg
# 2867       Maharashtra  Ratnagiri - sindhudurg
# 2865       Maharashtra  Ratnagiri - sindhudurg
# 2864       Maharashtra  Ratnagiri - sindhudurg
# 1436  Himachal Pradesh                Hamirpur
# 1435  Himachal Pradesh                Hamirpur
# 1434  Himachal Pradesh                Hamirpur
# 1438  Himachal Pradesh                Hamirpur
# 1432  Himachal Pradesh                Hamirpur
# 1437  Himachal Pradesh                Hamirpur
# 1433  Himachal Pradesh                Hamirpur
# 1441  Himachal Pradesh                Hamirpur
# 1439  Himachal Pradesh                Hamirpur
# 1440  Himachal Pradesh                Hamirpur
# 2651       Maharashtra              Aurangabad
# 2665       Maharashtra              Aurangabad
# 2664       Maharashtra              Aurangabad
# 2663       Maharashtra              Aurangabad
# 2662       Maharashtra              Aurangabad
# 2661       Maharashtra              Aurangabad
# 2659       Maharashtra              Aurangabad
# 2658       Maharashtra              Aurangabad
# 2657       Maharashtra              Aurangabad
# 2656       Maharashtra              Aurangabad
# 2655       Maharashtra              Aurangabad
# 2654       Maharashtra              Aurangabad
# 2653       Maharashtra              Aurangabad
# 2652       Maharashtra              Aurangabad
# 2650       Maharashtra              Aurangabad
# 2666       Maharashtra              Aurangabad
# 2667       Maharashtra              Aurangabad
# 2660       Maharashtra              Aurangabad
# 2669       Maharashtra              Aurangabad
# 2670       Maharashtra              Aurangabad
#
#                                  candidate sex   age category party_x  \
# 2866                  VINAYAK BHAURAO RAUT   M  60.0      GEN     SHS
# 2873  SUNIL ALIAS YASHWANT VASANT PEDNEKAR   M  47.0      GEN     IND
# 2872          ARUN HARISHCHANDRA MANJREKAR   M  59.0      GEN     IND
# 2871                 AJINKYA DHONDU GAWADE   M  48.0      GEN     IND
# 2870              VINOD HANUMANTRAO SAWANT   M  57.0      GEN    ABHM
# 2869                  BIRJE YASHWANT ANANT   M  71.0      GEN    BMUP
# 2868             ADV. DIPAK DATTARAM NEVGI   M  54.0      GEN   SP(I)
# 2867             ABHIJIT SHRIRAM HEGSHETYE   M  56.0      GEN    AAAP
# 2865                   NILESH NARAYAN RANE   M  33.0      GEN     INC
# 2864                   AYARE RAJENDRA LAHU   M  51.0      GEN     BSP
# 1436                     KAMAL KANTA BATRA   F  69.0      GEN    AAAP
# 1435                         URMILA SHARMA   F  58.0      GEN      SP
# 1434                   RAJINDER SINGH RANA   M  48.0      GEN     INC
# 1438                            AMIN CHAND   M  55.0       SC     IND
# 1432                   ANURAG SINGH THAKUR   M  39.0      GEN     BJP
# 1437                     SHIV DUTT VASISHT   M  61.0      GEN     SHS
# 1433                      RAKESH CHOUDHARY   M  38.0      GEN     BSP
# 1441                   RAJINDER SINGH RANA   M  47.0      GEN     IND
# 1439                          ASHISH KUMAR   M  34.0      GEN     IND
# 1440                      DEV RAJ BHARDWAJ   M  61.0      GEN     IND
# 2651          JEVRIKAR INDRAKUMAR DNYANOBA   M  40.0       SC     BSP
# 2665           TRIBHUVAN MADHUKAR PADMAKAR   M  45.0       SC     IND
# 2664              JAGDIP VISHWANATH SHINDE   M  31.0       SC     IND
# 2663            KAILAS CHANDRABHAN THENGDE   M  36.0      GEN     IND
# 2662            ANKUSH MUNJAJI TUPSAMUNDRE   M  39.0       SC     IND
# 2661               BANSODE UDHAV GOVARDHAN   M  31.0       SC     IND
# 2659               SUBHASH KALYANRAO LOMTE   M  62.0      GEN    AAAP
# 2658         SAYYAD SHAFIYODDIN VAHIYODDIN   M  46.0      GEN    WPOI
# 2657               GAYAKE SADASHIV AMBADAS   M  64.0      GEN      SP
# 2656   MOHMMAD KISMATWALA KASIM KISMATWALA   M  37.0      GEN    GaAP
# 2655            BANSWAL MANNALAL PREMCHAND   M  47.0       SC    PRCP
# 2654               JADHAV PUSHPA SHANTILAL   F  40.0       SC     ANC
# 2653       ABDUL KHUDUS ABDUL SAMAD SHAIKH   M  32.0      GEN    BMUP
# 2652                    PATIL NITIN SURESH   M  44.0      GEN     INC
# 2650            CHANDRAKANT BHAURAO KHAIRE   M  62.0      GEN     SHS
# 2666             DANDGE NANASAHEB DAMODHAR   M  44.0       SC     IND
# 2667                           NADEEM RANA   M  40.0      GEN     IND
# 2660             AHAMAD AZIZ AHAMAD MATEEN   M  53.0      GEN     IND
# 2669           DR. FEROZ KHAN MURTUZA KHAN   M  44.0      GEN     IND
# 2670               BALASAHEB ASARAM SARATE   M  45.0      GEN     IND
#
#                  party_symbol  general_votes  postal_votes  total_votes  \
# 2866              Bow & Arrow         492900           188       493088
# 2873           Auto- Rickshaw           7328             0         7328
# 2872                  Whistle           5999             0         5999
# 2871             Cup & Saucer           2331             1         2332
# 2870                  Coconut           1395             0         1395
# 2869                      Cot           1992             0         1992
# 2868            Battery Torch           2904             0         2904
# 2867                    Broom          12693             7        12700
# 2865                     Hand         342999            38       343037
# 2864                 Elephant          13084             4        13088
# 1436                    Broom          15281            48        15329
# 1435                  Bicycle           2327             1         2328
# 1434                     Hand         348871           761       349632
# 1438                Telephone            646             1          647
# 1432                    Lotus         446755          1280       448035
# 1437              Bow & Arrow            952             0          952
# 1433                 Elephant           5821             6         5827
# 1441           Sewing Machine           3677            10         3687
# 1439                  Almirah            603             0          603
# 1440                  Coconut           1690             2         1692
# 2651                 Elephant          37412             7        37419
# 2665                  Almirah           6135             0         6135
# 2664          Air Conditioner           1530             0         1530
# 2663                    Dolli           2123             0         2123
# 2662  Pen Nib with Seven Rays           2019             0         2019
# 2661             Cup & Saucer           1795             0         1795
# 2659                    Broom          11969             5        11974
# 2658                     Kite           2885             0         2885
# 2657                  Bicycle           2646             0         2646
# 2656                     Iron           1198             3         1201
# 2655                  Whistle            893             0          893
# 2654                      Bat           1037             1         1038
# 2653                      Cot           3774             1         3775
# 2652                     Hand         358812            90       358902
# 2650              Bow & Arrow         520559           343       520902
# 2666           Sewing Machine           5901             0         5901
# 2667              Ceiling Fan           2922             0         2922
# 2660           Auto- Rickshaw           1572             0         1572
# 2669                  Balloon            978             0          978
# 2670                  Coconut            880             0          880
#
#       total_electors party_y  total_votes_x_x  total_votes_y_x  difference_x  \
# 2866         1367362     INC           343037           883863     38.811105
# 2873         1367362     INC           343037           883863     38.811105
# 2872         1367362     INC           343037           883863     38.811105
# 2871         1367362     INC           343037           883863     38.811105
# 2870         1367362     INC           343037           883863     38.811105
# 2869         1367362     INC           343037           883863     38.811105
# 2868         1367362     INC           343037           883863     38.811105
# 2867         1367362     INC           343037           883863     38.811105
# 2865         1367362     INC           343037           883863     38.811105
# 2864         1367362     INC           343037           883863     38.811105
# 1436         1247699     INC           349632           828732     42.188790
# 1435         1247699     INC           349632           828732     42.188790
# 1434         1247699     INC           349632           828732     42.188790
# 1438         1247699     INC           349632           828732     42.188790
# 1432         1247699     INC           349632           828732     42.188790
# 1437         1247699     INC           349632           828732     42.188790
# 1433         1247699     INC           349632           828732     42.188790
# 1441         1247699     INC           349632           828732     42.188790
# 1439         1247699     INC           349632           828732     42.188790
# 1440         1247699     INC           349632           828732     42.188790
# 2651         1589395     INC           358902           976561     36.751621
# 2665         1589395     INC           358902           976561     36.751621
# 2664         1589395     INC           358902           976561     36.751621
# 2663         1589395     INC           358902           976561     36.751621
# 2662         1589395     INC           358902           976561     36.751621
# 2661         1589395     INC           358902           976561     36.751621
# 2659         1589395     INC           358902           976561     36.751621
# 2658         1589395     INC           358902           976561     36.751621
# 2657         1589395     INC           358902           976561     36.751621
# 2656         1589395     INC           358902           976561     36.751621
# 2655         1589395     INC           358902           976561     36.751621
# 2654         1589395     INC           358902           976561     36.751621
# 2653         1589395     INC           358902           976561     36.751621
# 2652         1589395     INC           358902           976561     36.751621
# 2650         1589395     INC           358902           976561     36.751621
# 2666         1589395     INC           358902           976561     36.751621
# 2667         1589395     INC           358902           976561     36.751621
# 2660         1589395     INC           358902           976561     36.751621
# 2669         1589395     INC           358902           976561     36.751621
# 2670         1589395     INC           358902           976561     36.751621
#
#       total_votes_x_y  total_votes_y_y  difference_y          d
# 2866            63299           901102      7.024621 -31.786484
# 2873            63299           901102      7.024621 -31.786484
# 2872            63299           901102      7.024621 -31.786484
# 2871            63299           901102      7.024621 -31.786484
# 2870            63299           901102      7.024621 -31.786484
# 2869            63299           901102      7.024621 -31.786484
# 2868            63299           901102      7.024621 -31.786484
# 2867            63299           901102      7.024621 -31.786484
# 2865            63299           901102      7.024621 -31.786484
# 2864            63299           901102      7.024621 -31.786484
# 1436           114534          1089778     10.509847 -31.678943
# 1435           114534          1089778     10.509847 -31.678943
# 1434           114534          1089778     10.509847 -31.678943
# 1438           114534          1089778     10.509847 -31.678943
# 1432           114534          1089778     10.509847 -31.678943
# 1437           114534          1089778     10.509847 -31.678943
# 1433           114534          1089778     10.509847 -31.678943
# 1441           114534          1089778     10.509847 -31.678943
# 1439           114534          1089778     10.509847 -31.678943
# 1440           114534          1089778     10.509847 -31.678943
# 2651            91789          1198221      7.660440 -29.091181
# 2665            91789          1198221      7.660440 -29.091181
# 2664            91789          1198221      7.660440 -29.091181
# 2663            91789          1198221      7.660440 -29.091181
# 2662            91789          1198221      7.660440 -29.091181
# 2661            91789          1198221      7.660440 -29.091181
# 2659            91789          1198221      7.660440 -29.091181
# 2658            91789          1198221      7.660440 -29.091181
# 2657            91789          1198221      7.660440 -29.091181
# 2656            91789          1198221      7.660440 -29.091181
# 2655            91789          1198221      7.660440 -29.091181
# 2654            91789          1198221      7.660440 -29.091181
# 2653            91789          1198221      7.660440 -29.091181
# 2652            91789          1198221      7.660440 -29.091181
# 2650            91789          1198221      7.660440 -29.091181
# 2666            91789          1198221      7.660440 -29.091181
# 2667            91789          1198221      7.660440 -29.091181
# 2660            91789          1198221      7.660440 -29.091181
# 2669            91789          1198221      7.660440 -29.091181
# 2670            91789          1198221      7.660440 -29.091181

# %%
df1.loc[df1['state']=='Dadra & Nagar Haveli']
# Out:
#                      state               pc_name  \
# 8143  Dadra & Nagar Haveli  Dadar & Nagar Haveli
# 8144  Dadra & Nagar Haveli  Dadar & Nagar Haveli
# 8145  Dadra & Nagar Haveli  Dadar & Nagar Haveli
# 8146  Dadra & Nagar Haveli  Dadar & Nagar Haveli
# 8147  Dadra & Nagar Haveli  Dadar & Nagar Haveli
# 8148  Dadra & Nagar Haveli  Dadar & Nagar Haveli
# 8149  Dadra & Nagar Haveli  Dadar & Nagar Haveli
# 8150  Dadra & Nagar Haveli  Dadar & Nagar Haveli
# 8151  Dadra & Nagar Haveli  Dadar & Nagar Haveli
# 8152  Dadra & Nagar Haveli  Dadar & Nagar Haveli
# 8153  Dadra & Nagar Haveli  Dadar & Nagar Haveli
#
#                          candidate sex   age category  party party_symbol  \
# 8143  KHULAT JANIYABHAI CHANDUBHAI   M  58.0       ST    NCP        Clock
# 8144    DELKAR MOHANBHAI SANJIBHAI   M  51.0       ST    INC         Hand
# 8145      PATEL NATUBHAI GOMANBHAI   M  41.0       ST    BJP        Lotus
# 8146   PATEL HEMANTBHAI KESHAVBHAI   M  43.0       ST    BSP     Elephant
# 8147          KISHAN NATHU GHUTIYA   M  44.0       ST    SHS  Bow & Arrow
# 8148     PATEL CHHOTUBHAI BABUBHAI   M  49.0       ST   AAAP        Broom
# 8149     VIJAYBHAI NATHUBHAI BHOYA   M  30.0       ST  JD(U)        Arrow
# 8150      UMEDBHAI LALLUBHAI PATEL   M  47.0       ST   BMUP          Cot
# 8151      KAMUBEN KHALPABHAI PATEL   F  44.0       ST    IND      Coconut
# 8152     PRAKASH VANSHA KHANVELKAR   M  57.0       ST    IND      Whistle
# 8153   BHURKUD DILIPBHAI NAVJIBHAI   M  43.0       ST    IND         Kite
#
#       general_votes  postal_votes  total_votes  total_electors
# 8143           1611             0         1611          196597
# 8144          74576             0        74576          196597
# 8145          80790             0        80790          196597
# 8146            982             0          982          196597
# 8147            378             0          378          196597
# 8148            621             0          621          196597
# 8149            232             0          232          196597
# 8150            348             0          348          196597
# 8151            418             0          418          196597
# 8152           1214             0         1214          196597
# 8153           1154             0         1154          196597

# %% [markdown]
# # 9

# %%
df1_f=pd.DataFrame(df1.groupby(['pc_name','party'])['total_votes'].sum()).reset_index()
df1_g=pd.DataFrame(df1.groupby('pc_name')['total_votes'].sum()).reset_index()


df1_h=pd.merge(df1_f,df1_g,on='pc_name')
df1_h['difference']=(df1_h['total_votes_x']/df1_h['total_votes_y'])*100
df1_j=df1_h.loc[df1_h['party']=='BJP'].sort_values(by='difference',ascending=False)

df2_f=pd.DataFrame(df2.groupby(['pc_name','party'])['total_votes'].sum()).reset_index()
df2_g=pd.DataFrame(df2.groupby('pc_name')['total_votes'].sum()).reset_index()


df2_h=pd.merge(df2_f,df2_g,on='pc_name')
df2_h['difference']=(df2_h['total_votes_x']/df2_h['total_votes_y'])*100
df2_j=df2_h.loc[df2_h['party']=='BJP'].sort_values(by='difference',ascending=False)



df_k=pd.merge(df1_j,df2_j,on=['pc_name','party'])
df_k['loss vote share %']=df_k['difference_y']- df_k['difference_x']
vote_share1=df_k.sort_values(by='loss vote share %',ascending=True)
vote_share1[['pc_name','loss vote share %']].head(5)
# Out:
#            pc_name  loss vote share %
# 131     Narsapuram         -48.930635
# 142  Visakhapatnam         -46.290430
# 179      Tirupati          -43.854047
# 38          Sangli         -15.998910
# 84     Daman & diu         -11.674174

# %%
df1_f=pd.DataFrame(df1.groupby(['pc_name','party'])['total_votes'].sum()).reset_index()
df1_g=pd.DataFrame(df1.groupby('pc_name')['total_votes'].sum()).reset_index()


df1_h=pd.merge(df1_f,df1_g,on='pc_name')
df1_h['difference']=(df1_h['total_votes_x']/df1_h['total_votes_y'])*100
df1_j=df1_h.loc[df1_h['party']=='INC'].sort_values(by='difference',ascending=False)

df2_f=pd.DataFrame(df2.groupby(['pc_name','party'])['total_votes'].sum()).reset_index()
df2_g=pd.DataFrame(df2.groupby('pc_name')['total_votes'].sum()).reset_index()


df2_h=pd.merge(df2_f,df2_g,on='pc_name')
df2_h['difference']=(df2_h['total_votes_x']/df2_h['total_votes_y'])*100
df2_j=df2_h.loc[df2_h['party']=='INC'].sort_values(by='difference',ascending=False)



df_k=pd.merge(df1_j,df2_j,on=['pc_name','party'])
df_k['loss vote share %']=df_k['difference_y']- df_k['difference_x']
vote_share2=df_k.sort_values(by='loss vote share %',ascending=True)
vote_share2[['pc_name','loss vote share %']].head(5)
# Out:
#                     pc_name  loss vote share %
# 75   Ratnagiri - sindhudurg         -31.786484
# 42                 Hamirpur         -31.678943
# 95               Aurangabad         -29.091181
# 82           ARUNACHAL WEST         -24.009191
# 177                 Raiganj         -22.237169

# %% [markdown]
# # 10

# %%
df1 = pd.read_csv('constituency_wise_results_2014.csv')

# %%
nota=pd.DataFrame(df1.groupby(['pc_name','party'])['total_votes'].sum()).reset_index()
nota2=(df1.groupby('pc_name')['total_votes'].sum()).reset_index()

nota3=pd.merge(nota,nota2,on='pc_name')
nota3['vote_share']=(nota3['total_votes_x']/nota3['total_votes_y'])*100

nota_vote1 = nota3.loc[(nota3['party']=='NOTA')].sort_values(by='vote_share',ascending=False).head(1)
nota_vote1[['pc_name','party','total_votes_x','vote_share']]
# Out:
#         pc_name party  total_votes_x  vote_share
# 4081  Nilgiris   NOTA          46559     4.98984

# %%
nota=pd.DataFrame(df2.groupby(['pc_name','party'])['total_votes'].sum()).reset_index()
nota2=(df2.groupby('pc_name')['total_votes'].sum()).reset_index()

nota3=pd.merge(nota,nota2,on='pc_name')
nota3['vote_share']=(nota3['total_votes_x']/nota3['total_votes_y'])*100

nota_vote2=nota3.loc[(nota3['party']=='NOTA')].sort_values(by='vote_share',ascending=False).head(1)
nota_vote2[['pc_name','party','total_votes_x','vote_share']]
# Out:
#              pc_name party  total_votes_x  vote_share
# 2030  Gopalganj (SC)  NOTA          51660     5.04061

# %% [markdown]
# # 11

# %%
# Calculate the total votes for each state
state_total_votes = df2.groupby('state')['total_votes'].sum()

# Calculate the total votes for each party in each state
party_state_votes = df2.groupby(['state', 'party'])['total_votes'].sum()

# Calculate the vote share for each party in each state
party_state_vote_share = (party_state_votes / state_total_votes) * 100

# Merge this vote share back into the original dataframe
df2_11 = df2.merge(party_state_vote_share.rename('party_vote_share'), on=['state', 'party'])

#candidate elected
e=df2_11.groupby(['state','pc_name'])['total_votes'].max().reset_index()
r=pd.merge(df2_11,e,on=['state','pc_name','total_votes'])

#r.loc[r['state']=='Assam']
vote_ten= r.loc[r['party_vote_share']<10]
vote_ten[['state','pc_name','party','party_vote_share']].sort_values(by='party_vote_share',ascending=False).head(10)
# Out:
#          state          pc_name  party  party_vote_share
# 153  Karnataka           Hassan  JD(S)          9.668060
# 279     Punjab       Hoshiarpur    BJP          9.628793
# 278     Punjab        Gurdaspur    BJP          9.628793
# 73       Bihar         Vaishali    LJP          8.244362
# 74       Bihar     Hajipur (SC)    LJP          8.244362
# 75       Bihar  Samastipur (SC)    LJP          8.244362
# 76       Bihar         Khagaria    LJP          8.244362
# 77       Bihar           Nawada    LJP          8.244362
# 78       Bihar       Jamui (SC)    LJP          8.244362
# 57       Bihar       Kishanganj    INC          8.074224
